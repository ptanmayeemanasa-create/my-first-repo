# %%
Hardware refers to the physical parts of a computer that you can see and touch.
Example: Keyboard
Software refers to the programs or instructions that tell the hardware what to do. You cannot touch it.
Example: Microsoft Word
